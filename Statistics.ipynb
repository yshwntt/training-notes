# %% [markdown]
# Statistics - sciense of organising summarize and analyze and draw connection out of it

# %% [markdown]
# Descriptive - mean median mode, standard deveation , variance and range
# Inferentisl - based on population, sample data  come to a concluison

# %% [markdown]
# Numerical - discrete : quantifyy a data and catagorical data eg : car brands

# %% [markdown]
# levels of measurment : Qualitative : operations are meaning less
#                       Quantitative : Nominal - eg can rank summer winter not the sequence of occurence
#                                       Ordnal

# %% [markdown]
# Interval : ordered data have a fixed range eg: car gears clesius and fahrehite(20°C is not twice as hot as 10°C)
# Ratio : kelvin (data is meaningfull i.e retaled 200 K is twice as hot as 100 K )

# %% [markdown]
# Types of data: 1) catagorical - straiforward like yes or no
# (ML model takes numerical data so coneverts catagorical data into numerical data before passing model)

# %% [markdown]
# mean = sum of n/count of n
# median = organise the extreme outliers in asc or dsc pick the central if its odd if even pick the mean of two
# mode = Most repeated value in the data

# %% [markdown]
# Measure of dispersion : Range : ran(up)-ran(low)
#                         variance : mesurace of dispersion in dataset
#                         standard deviation : square of vaariance : my first data point is one sd away from central tendance

# %% [markdown]
# symmetical variation
# asymetrical variation
# skewness:![image.png](attachment:6a4ddf08-99c1-4d20-abda-b867949f3a0d.png)

# %% [markdown]
# overfittimg : having extreme outliers

# %% [markdown]
# Random Variable : set is all possibe values from a random expiriment
# Discrete RV : contable random variable
# Continuous RV :

# %% [markdown]
# Sets : Collection of objects
