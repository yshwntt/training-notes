# %% [markdown]
# scatter plot for data distribution -- variance -- corelation of central point --

# %% [markdown]
# pie chart - distribution of data - subplotting

# %% [markdown]
# curves - compare multiple datapoints - how data is changed over a period of time - how data is being distributed

# %% [markdown]
# mappo=lot - distribution of data at particular plotb

# %% [markdown]
# plotly and cuffling - 3d graphs for better visuvalization

# %% [markdown]
# mat.lib 2d library

# %% [markdown]
# stacked barchats - horizontal plotting

# %% [markdown]
# box plot (outlier in data)(5 parameters - max, min, quatel 1 and quatel 3)

# %% [markdown]
# outlier in data : An outlier is a value that is very different from the rest of the data.
# Example:
# Normal heights: 5.5ft – 6ft
# One person: 7.5ft
# That 7.5ft is an outlier

# %% [markdown]
# Area chart - area covered

# %% [markdown]
# surface chart - 3 D - reasearch part

# %% [markdown]
# Scattered 3D part

# %% [markdown]
# bubble chart - 3d plotting data points

# %% [markdown]
# Heat Map - Correlation between data points

# %% [markdown]
# correlation - eg : age incre and experi incre - so maintain a single coloum

# %% [markdown]
# PANDAS AND NUMPY

# %% [markdown]
# import pandas as pd
#
# titanic_train = pd.read_csv(r"file_path.csv")
# titanic_train

# %% [markdown]
# titanic_train(DataFrame Object)
# .tail(10)
# .dtypes
# .dtypes == 'object'
# class.describe()- how many uniquw counts are there,  top, just count
# .coloums - list of coloums
# .head() - top data
# .dtypes - tells data types
# .isnull() - check nulls
# .mean()
# Can directly pass index values
# Syntax : missing = np.where(titanic_train["Age"].isnull() == True)
# missing
#
# pandas.dataframe syntax = pd.DataFrame(d, index = ['a','b'])

# %% [markdown]
# reset INdex = ![image.png](attachment:1adf0d35-61aa-4d42-b0d4-fd40314340a2.png) - create new index

# %% [markdown]
# Set Index - setting index

# %% [markdown]
# import syntax:
# import numpy as np
# import pandas as pd
# import os
# import matplotlib.pyplot as plt
# %matplotlib inline
#
# import numpy as np → Import NumPy (for arrays, math operations)
# import pandas as pd → Import Pandas (for DataFrames, data handling)
# import os → Import OS module (for file paths, folders, system operations)
# import matplotlib.pyplot as plt → Import Matplotlib for plotting graphs
# %matplotlib inline → Shows plots directly inside Jupyter Notebook

# %% [markdown]
# Data Manupulation

# %% [markdown]
# .fillna = add a value with new value like remove null values and fill it with something

# %% [markdown]
# group by and mean syntax:
# byComp = df.groupby('Company')
# print("\nGrouping by 'Company' column and listing mean sales\n",'-'*55, sep='')
# print(byComp.mean(numeric_only=True))

# %% [markdown]
# .sum() - summation
# .transpose() - all will become coloumns with respective data points
# pd.concat(a,b,c, axis = 1) - concatination
# pd.merge(left,right,how='inner', on= 'key') - synatx for joins(inner join)

# %% [markdown]
# .apply(lambda x : np.log(x)) - same as lambda function using .apply (create new opertaion for current line

# %% [markdown]
# .sort_values - sort values asc or desc
